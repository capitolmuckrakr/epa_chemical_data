# %%
import pandas as pd, sqlite3

# %%
pd.options.display.min_rows = 200
pd.options.display.max_rows = 1000

# %%
conn = sqlite3.connect("epa_chemical_data_cleaned.db")

# %%
consumer_table_query = "SELECT * FROM [2020-CDR-Consumer-Filtered-Cleaned]"

# %%
df_consumer_table = pd.read_sql_query(consumer_table_query, conn)

# %%
industrial_table_query = "SELECT * FROM [2020-CDR-Industrial-Filtered-Cleaned]"

# %%
df_industrial_table = pd.read_sql_query(industrial_table_query, conn)

# %%
manufacturing_table_query = "SELECT * FROM [2020-CDR-Manufacturing-Filtered-Cleaned]"

# %%
df_manufacturing_table = pd.read_sql_query(manufacturing_table_query, conn)

# %%
aggregated_table_query = "SELECT * FROM [2020_CDR_Nationally_Aggregated_Production_Volumes_Filtered]"

# %%
df_aggregated_table = pd.read_sql_query(aggregated_table_query, conn)

# %%
manufacturing_selected_cols = [
    'DOMESTIC PARENT COMPANY NAME CLEANED',
    'CHEMICAL NAME',
    'CHEMiCAL ID'
    'SITE NAME',
    'SITE ADDRESS LINE1',
    'SITE CITY CLEANED',
    'SITE STATE',
    'ACTIVITY',
    '2019 DOMESTIC PV', 
    '2019 IMPORT PV', 
    '2019 PV', 
    '2019 NATIONALLY AGGREGATED PV',
    'IMPORTED CHEM NEVER AT SITE',
    '2019 V USED ON-SITE', 
    '2019 V EXPORTED',
    'PERCENT BYPRODUCT', 
    'WORKERS CODE', 
    'WORKERS', 
    'MAX CONC CODE',
    'MAXIMUM CONCENTRATION'
]

# %%
industrial_selected_cols = [
    'DOMESTIC_PARENT_COMPANY_NAME_CLEAN',
    'CHEMICAL NAME',
    'CHEMICAL ID',
    'SITE NAME',
    'SITE ADDRESS LINE1',
    'SITE_CITY_CLEANED',
    'SITE STATE',
    'ACTIVITY',
    '2019 DOMESTIC PV', 
    '2019 IMPORT PV', 
    '2019 PV', 
    '2019 NATIONALLY AGGREGATED PV',
    'IMPORTED CHEM NEVER AT SITE',
    '2019 V USED ON-SITE', 
    '2019 V EXPORTED',
    'PERCENT BYPRODUCT', 
    'WORKERS CODE', 
    'WORKERS', 
    'MAX CONC CODE',
    'MAXIMUM CONCENTRATION'
]

# %%
consumer_selected_cols = [
    'DOMESTIC PARENT COMPANY NAME CLEANED',
    'CHEMICAL NAME',
    'CHEMICAL ID',
    'SITE NAME',
    'SITE ADDRESS LINE1',
    'SITE CITY CLEANED',
    'SITE STATE',
    'ACTIVITY',
    '2019 DOMESTIC PV', 
    '2019 IMPORT PV', 
    '2019 PV', 
    '2019 NATIONALLY AGGREGATED PV',
    'IMPORTED CHEM NEVER AT SITE',
    '2019 V USED ON-SITE', 
    '2019 V EXPORTED',
    'PERCENT BYPRODUCT', 
    'WORKERS CODE', 
    'WORKERS', 
    'MAX CONC CODE',
    'MAXIMUM CONCENTRATION'
]

# %%
df_industrial_table[industrial_selected_cols]
# Out:
#                     DOMESTIC_PARENT_COMPANY_NAME_CLEAN  \
# 0                                                  CBI
# 1                                             CELANESE
# 2                                  LANXESS CORPORATION
# 3                                  SOLVAY HOLDING INC.
# 4                         MARUBENI AMERICA CORPORATION
# 5                                         INNOSPEC INC
# 6                                NEWMARKET CORPORATION
# 7                 BRIDGESTONE PROCUREMENT HOLDINGS USA
# 8                               MICHELIN NORTH AMERICA
# 9                         LION COPOLYMER HOLDINGS, LLC
# 10                             EXXON MOBIL CORPORATION
# 11                             EXXON MOBIL CORPORATION
# 12                                          BASF CORP.
# 13                                   SHELL CHEMICAL LP
# 14                                KOCH INDUSTRIES INC.
# 15                                   SHELL CHEMICAL LP
# ...

# %%
df_consumer_table[consumer_selected_cols]
# Out:
#                   DOMESTIC PARENT COMPANY NAME CLEANED  \
# 0                                                  CBI
# 1                                             CELANESE
# 2                                             CELANESE
# 3                                  LANXESS CORPORATION
# 4                                  SOLVAY HOLDING INC.
# 5                         MARUBENI AMERICA CORPORATION
# 6                                         INNOSPEC INC
# 7                                NEWMARKET CORPORATION
# 8                 BRIDGESTONE PROCUREMENT HOLDINGS USA
# 9                               MICHELIN NORTH AMERICA
# 10                        LION COPOLYMER HOLDINGS, LLC
# 11                             EXXON MOBIL CORPORATION
# 12                                          BASF CORP.
# 13                                   SHELL CHEMICAL LP
# 14                                KOCH INDUSTRIES INC.
# 15                                   SHELL CHEMICAL LP
# ...
